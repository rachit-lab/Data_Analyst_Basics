# %%
import pandas as pd

df = pd.read_csv('kc_house_data.csv')
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='str')

# %%
y = df['price']
house_features = ['bedrooms' , 'bathrooms' , 'floors' , 'sqft_living' , 'sqft_lot', 'waterfront']
x = df[house_features]
x.describe()
# Out:
#            bedrooms     bathrooms        floors   sqft_living      sqft_lot  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean       3.370842      2.114757      1.494309   2079.899736  1.510697e+04
# std        0.930062      0.770163      0.539989    918.440897  4.142051e+04
# min        0.000000      0.000000      1.000000    290.000000  5.200000e+02
# 25%        3.000000      1.750000      1.000000   1427.000000  5.040000e+03
# 50%        3.000000      2.250000      1.500000   1910.000000  7.618000e+03
# 75%        4.000000      2.500000      2.000000   2550.000000  1.068800e+04
# max       33.000000      8.000000      3.500000  13540.000000  1.651359e+06
#
#          waterfront
# count  21613.000000
# mean       0.007542
# std        0.086517
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
x.head()
# Out:
#    bedrooms  bathrooms  floors  sqft_living  sqft_lot  waterfront
# 0         3       1.00     1.0         1180      5650           0
# 1         3       2.25     2.0         2570      7242           0
# 2         2       1.00     1.0          770     10000           0
# 3         4       3.00     1.0         1960      5000           0
# 4         3       2.00     1.0         1680      8080           0

# %%
from sklearn.tree import DecisionTreeRegressor

house_model = DecisionTreeRegressor(random_state=1)

house_model.fit(x,y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print('Making predicitions for the following 5 houses :')
print(x.head())
print("The predicitions are :")
print(house_model.predict(x.head()))
# Out:
# Making predicitions for the following 5 houses :
#    bedrooms  bathrooms  floors  sqft_living  sqft_lot  waterfront
# 0         3       1.00     1.0         1180      5650           0
# 1         3       2.25     2.0         2570      7242           0
# 2         2       1.00     1.0          770     10000           0
# 3         4       3.00     1.0         1960      5000           0
# 4         3       2.00     1.0         1680      8080           0
# The predicitions are :
# [221900. 538000. 180000. 604000. 510000.]

# %%
## mean absolute error

from sklearn.metrics import mean_absolute_error

predicted_house_sales = house_model.predict(x)
mean_absolute_error(y, predicted_house_sales)
# Out:
# 1802.541232899952

# %%
##Overfitting and Underfitting

from sklearn.model_selection import train_test_split

train_x, val_x, train_y, val_y = train_test_split(x,y, random_state=0)

house_model = DecisionTreeRegressor()

house_model.fit(train_x,train_y)

val_predictions = house_model.predict(val_x)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 198334.60526153469

# %%
def get_mae(max_leaf_nodes, train_x, val_x, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_x,train_y)
    preds_val = model.predict(val_x)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

# %%
leaves = {}
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_x, val_x, train_y, val_y)
    print("Max leaf nodes : %d \n Mean Absolute error : %d" %(max_leaf_nodes,my_mae))
    leaves[max_leaf_nodes] = my_mae
# Out:
# Max leaf nodes : 5
#  Mean Absolute error : 176025
# Max leaf nodes : 50
#  Mean Absolute error : 156496
# Max leaf nodes : 500
#  Mean Absolute error : 159950
# Max leaf nodes : 5000
#  Mean Absolute error : 191467

# %%
print(leaves)
best_tree_size = min(leaves, key=leaves.get)
# Out:
# {5: 176025.62250951744, 50: 156496.5247333935, 500: 159950.05510963072, 5000: 191467.86108619987}

# %%
best_tree_size
# Out:
# 50

# %%
final_model = DecisionTreeRegressor(max_leaf_nodes=best_tree_size, random_state=1)
final_model.fit(x,y)
print(final_model)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=50, random_state=1)

# %%
final_model
# Out:
# DecisionTreeRegressor(max_leaf_nodes=50, random_state=1)

# %%
print(final_model.predict(x.head()))
# Out:
# [336717.38730853 555005.32395687 277444.1563981  564331.76888889
#  397763.92310078]
